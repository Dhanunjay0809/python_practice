# %%
import re

text = "car"
pattern = r"[arn]"

matches = re.findall(pattern, text)
print("Matches:", matches)
# Out:
# Matches: ['a', 'r']

# %%
text = "hello"
pattern = r"[a-n]"

matches = re.findall(pattern, text)
print("Matches:", matches)
# Out:
# Matches: ['h', 'e', 'l', 'l']

# %%
text = "2019"
pattern = r"[0123]"

matches = re.findall(pattern, text)
print("Matches:", matches)
# Out:
# Matches: ['2', '0', '1']

# %%
text = "Room 42"
pattern = r"[0-9]"

matches = re.findall(pattern, text)
print("Matches:", matches)
# Out:
# Matches: ['4', '2']

# %%
text = "12, 67, 45"
pattern = r"[0-5][0-9]"

matches = re.findall(pattern, text)
print("Matches:", matches)
# Out:
# Matches: ['12', '45']

# %%
text = "Hello123!"
pattern = r"[a-zA-Z]"

matches = re.findall(pattern, text)
print("Matches:", matches)
# Out:
# Matches: ['H', 'e', 'l', 'l', 'o']

# %%
text = "5+3=8"
pattern = r"[+]"

matches = re.findall(pattern, text)
print("Matches:", matches)
# Out:
# Matches: ['+']

# %%
### Flags

# %%
import re

text = "café"
print(re.findall(r"\w+", text, re.ASCII))   # only ASCII chars
# Out:
# ['caf']

# %%
import re

text = "hello HELLO HeLLo"
print(re.findall(r"hello", text))
# Out:
# ['hello']

# %%
import re

text = "hello HELLO HeLLo"
print(re.findall(r"hello", text, re.I))
# Out:
# ['hello', 'HELLO', 'HeLLo']

# %%
import re

text = "Hello\nWorld"
print(re.findall(r"^World", text))
# Out:
# []

# %%
import re

text = "Hello\nWorld"
print(re.findall(r"^World", text, re.M))
# Out:
# ['World']

# %%
import re

text = "café"
print(re.findall(r"\w+", text))
# Out:
# ['café']

# %%
re,unicode(unicode matching)
# Out:
# ['नमस', 'त']

# %%
import re

text = "नमस्ते"
print(re.findall(r"\w+", text ))
# Out:
# ['नमस', 'त']
